# %%
# !pip3 install -U finance-datareader
# Out:
# ...
#   Using cached finance_datareader-0.9.50-py3-none-any.whl (19 kB)
# ...
#   Using cached requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# ...
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# ...
#   Using cached lxml-4.9.2-cp310-cp310-macosx_11_0_arm64.whl
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 813.1 kB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 782.2 kB/s eta 0:00:00m eta 0:00:010:01:02
# ...
#   Using cached pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
# ...
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# ...
#   Using cached urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
# ...
#   Using cached charset_normalizer-3.0.1-cp310-cp310-macosx_11_0_arm64.whl (122 kB)
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
import FinanceDataReader as fdr

fdr.__version__
# Out:
# '0.9.50'

# %%
 fdr.__version__
# Out:
# '0.9.50'

# %%
df_krx = fdr.StockListing('KRX')

# %%
df_krx.shape
# Out:
# (2700, 17)

# %%
df_krx
# Out:
#         Code        ISU_CD      Name Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI          61300          2
# 1     373220  KR7373220003  LG에너지솔루션  KOSPI         511000          1
# 2     000660  KR7000660001    SK하이닉스  KOSPI          91000          2
# 3     207940  KR7207940008  삼성바이오로직스  KOSPI         783000          2
# 4     051910  KR7051910008      LG화학  KOSPI         669000          1
# ...      ...           ...       ...    ...    ...     ...        ...
# 2695  267810  KR7267810000        앙츠  KONEX  일반기업부    1093          0
# 2696  215050  KR7215050006   비엔디생활건강  KONEX  일반기업부     912          0
# 2697  267060  KR7267060002     명진홀딩스  KONEX  일반기업부     181          0
# 2698  308700  KR7308700004       테크엔  KONEX  일반기업부     410          1
# 2699  322190  KR7322190000        베른  KONEX  일반기업부     104          2
#
#       Changes  ChagesRatio    Open    High     Low    Volume        Amount  \
# ...

# %%
import datetime

# 시작일자와 종료일자 설정
end_date = datetime.datetime.now()
start_date = end_date - datetime.timedelta(days=365)

# 삼성전자의 주가 데이터 가져오기
samsung = fdr.DataReader('005930', start_date, end_date)

# 결과 출력
print(samsung)
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-02-28  71100  72100  71000  72100  17781783  0.002782
# 2022-03-02  72300  72400  71500  71700  12481430 -0.005548
# 2022-03-03  72300  73100  72200  72900  13232638  0.016736
# 2022-03-04  72700  72700  71200  71500  13409634 -0.019204
# 2022-03-07  70000  70600  69900  70100  18617138 -0.019580
# ...           ...    ...    ...    ...       ...       ...
# 2023-02-20  62900  63000  61800  62700  12908073  0.001597
# 2023-02-21  62700  62800  62000  62100   7665046 -0.009569
# 2023-02-22  61500  61800  61000  61100  11959088 -0.016103
# 2023-02-23  61700  62500  61500  62000  13047099  0.014730
# 2023-02-24  62300  62600  61300  61300  10134614 -0.011290
#
# [247 rows x 6 columns]

# %%
import pandas as pd

# 삼성전자 종목코드: 005930
df = fdr.DataReader('005930', '2022-02-26', '2021-02-27', 'minute1')

# 인덱스를 datetime 형태로 변경
df.index = pd.to_datetime(df.index)

print(df)
# Out:
# HTTP Error 400: Bad Request  - symbol "005930"not found or invalid periods
# Empty DataFrame
# Columns: []
# Index: []

# %%
# !pip3 install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.7.0-cp310-cp310-macosx_11_0_arm64.whl (7.3 MB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached Pillow-9.4.0-cp310-cp310-macosx_11_0_arm64.whl (3.0 MB)
# ...
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# ...
#   Using cached contourpy-1.0.7-cp310-cp310-macosx_11_0_arm64.whl (229 kB)
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
#   Using cached kiwisolver-1.4.4-cp310-cp310-macosx_11_0_arm64.whl (63 kB)
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import FinanceDataReader as fdr

# 시작일자와 종료일자 설정
end_date = datetime.datetime.now()
start_date = end_date - datetime.timedelta(days=365)

# 삼성전자의 주가 데이터 가져오기
samsung = fdr.DataReader('005930', start_date, end_date)


samsung
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-02-28  71100  72100  71000  72100  17781783  0.002782
# 2022-03-02  72300  72400  71500  71700  12481430 -0.005548
# 2022-03-03  72300  73100  72200  72900  13232638  0.016736
# 2022-03-04  72700  72700  71200  71500  13409634 -0.019204
# 2022-03-07  70000  70600  69900  70100  18617138 -0.019580
# ...           ...    ...    ...    ...       ...       ...
# 2023-02-20  62900  63000  61800  62700  12908073  0.001597
# 2023-02-21  62700  62800  62000  62100   7665046 -0.009569
# 2023-02-22  61500  61800  61000  61100  11959088 -0.016103
# 2023-02-23  61700  62500  61500  62000  13047099  0.014730
# 2023-02-24  62300  62600  61300  61300  10134614 -0.011290
#
# [247 rows x 6 columns]

# %%
df = samsung

# 데이터 시각화
plt.plot(df.index, df['Close'])
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Samsung Electronics Stock Price')
plt.show()
